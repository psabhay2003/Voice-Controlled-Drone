# %%
import torch
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# CUDA version: 12.6

# %%
# !pip install -q transformers accelerate evaluate jiwer tensorboard audiomentations librosa soundfile
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 54.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 11.2 MB/s eta 0:00:00

# %%
# !unzip dataset_2_0.zip
# Out:
# Archive:  dataset_2_0.zip
#    creating: downloaded_audio_fixed_to_mp3/
#   inflating: downloaded_audio_fixed_to_mp3/3 meters forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/A bit more to the other side. Left by 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/A bit more to the other side. Left by 6 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/advance 6 meters forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/advance a little.mp3
#   inflating: downloaded_audio_fixed_to_mp3/advance forward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 5 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 5 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 5 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 5 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 5 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Advance forward 5 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/After 2 meters turn right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/after 2 meters turn right_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright drone, move left.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright drone, move right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright drone, take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, get the drone airborne. Take off_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, land right away.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, let's get this thing in the air. Take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Alright, let's get this thing in the air. Take off_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/And... freeze. Stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend 2 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/ascend 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend down 10 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend down 10 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend down 10 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend down 10 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend down 10 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend down 10 meter from current position_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up 10 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up 10 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up 10 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up 10 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up 10 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up 10 meter from current position_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up to 55 meters high.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascend up to 55 meters high_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Ascent up to 10m height.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Assend 10 meter height.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Assend up by 17 m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Assend up to 12 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/back up 30m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/back up 30m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/back up 30m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/back up 30m.mp3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it back to base, prepare to land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it back to base, prepare to land_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home and land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring it home. Land in the designated zone_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring the altitude lower. Down by 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Bring the altitude lower. Down by 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/bring the drone back by 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can we slide left a bit.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you ascend Up by 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you ascend Up by 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you go backward by about 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you go backward by about 7 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you go backward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you go down.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you go forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you go up.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you move left.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you move right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you pan left by about 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you pan left by about 5 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you please go forward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you please go forward 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you take off right away.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Can you take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Cease all movement. Stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Check that corner. Go left 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Check the perimeter. Go right 12 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Climb up 3 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/climb up by 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Come backward 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/come down 30m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/come down 30m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/come down 30m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/come down 30m.mp3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Come down 40 meter straight.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Come down 40 meters straight.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Come down by 15 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Create some distance, go backward 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Create some distance, go backward 5 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Decrease your height. Go down by 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/descend 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 2 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 5 meters_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 5 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 5 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 5 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 5 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend 5 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/descend 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/descend 5m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend after 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/descend by 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/descend down by 100 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/descend down by 19 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/descend down by 21m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Descend down by 60 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/do not move.mp3
#   inflating: downloaded_audio_fixed_to_mp3/don't move 0m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Don't move an inch, stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Don't move an inch, stop_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/don't move.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/don't move.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/don't move.mp3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Don’t move stop at your current location.mp3
#   inflating: downloaded_audio_fixed_to_mp3/down 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Down.mp3
#   inflating: downloaded_audio_fixed_to_mp3/down_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone begin landing right now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone climb up 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone descend slowly, land now_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly backward without delay.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly backwards 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly down a litle.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly down quickly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly forward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly left for diatance.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly left.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone fly up higher.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone freeze in place_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go down 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go down 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go down 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone go down 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go down 3 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go down 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go down gently.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go down.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go downward 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go forward without delay.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone Go Left 10m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 2 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go left exactly 85 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 2 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right 5m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right to 30 meters distance.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go straight ahead 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go straight ahead 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go straight ahead 3 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go straight ahead 3 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go straight ahead 3 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go straight ahead 3 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go straight ahead 3 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go up 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go up 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go up 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone go up 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_11.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head forward_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the left.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the left_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the left_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the left_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the left_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the left_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the left_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the right_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the right_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the right_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the right_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the right_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone head to the right_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone hold position. Stop_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone land after 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone land now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone land right now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone land right now_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone land safely to ground.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone land safely to ground_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone land straight on ground.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone lift and take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone lift and take off_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone lift off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move backward 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move backward 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move backward slowly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move backward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move backwards 2 metres.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move backwards instantly now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move down 1 meter_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move downwards without delay.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move forward 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move forward 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move forward straight.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move left 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move left 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move left 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone move left 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move slightly to left.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move slightly to left_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move slightly to right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up 1 meter_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up 1 meter_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up 1 meter_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up 1 meter_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up 1 meter_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up 1 meter_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone move up without delay.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone pause.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone quickly take off upward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone quickly take off upward_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone retreat backward_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone reverse 2 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone rise uo after 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone rise up 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone rise up immediately now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift left 5 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone shift right 5 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone should go backward quickly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone should go forward immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone slide right 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone stop after 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone stop after 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone stop after 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone stop after 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone stop immediately here.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone stop immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone stop moving.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone stop within 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone Stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off 2 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off instantly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off instantly_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off straight up.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone take off straight up_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone turn left 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone turn left 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone turn left two meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone turn righ 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone turn right 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone turn right 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone turn right 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drone turn right and move 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone up 5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone up after 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, advance. Go forward 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, ascend now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, descend now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 0.5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward 9 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go backward immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 0.5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go down 9 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 0.5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward 9 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go forward immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 0.5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left 9 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go left immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 0.5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right 9 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go right immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 0.5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 7 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, go up 9 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, halt now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, land immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, land now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, land now_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, move down 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, move left now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, move right now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, move up immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please go backward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please go down.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please go forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please go left.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please go right.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please go up.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please stop after 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, please take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, shift left now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, shift right now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, stop immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, stop now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, take off immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, take off now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Drone, take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drop 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/drop down 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop!.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Emergency stop_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Find a safe spot and land the drone.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Find a safe spot and land the drone_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/fly 0m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/fly 25m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/fly 25m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/fly 25m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/fly 25m.mp3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/fly 5m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/fly ride 10m ahead.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Fly right 10 meters ahead.mp3
#   inflating: downloaded_audio_fixed_to_mp3/freeze now.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Freeze! Just stop all movement.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Freeze! Just stop all movement_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/From here rise up to 35 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/From here, rise up to 6 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Get above it all. Up 10 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Get above the treeline. Go up 9 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Get above the treeline. Go up 9 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Get ready and land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Get ready and take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go 3 meters forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go 5 meters up from here.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go 6 meters forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go back 1-2m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 10m from current position.m4a_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 2 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go Backward 2m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 4 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 5 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 5 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 5 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 5 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 5 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward 5 meter from current position_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backward 5m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward after 3 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward after 3 meter_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward and stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward at once.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go Backward by 12m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward from here.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward further.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward quickly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward right away.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward slowly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward smoothly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward until I say stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward upto 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backwards 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backwards 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backwards 3 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backwards 3 meters_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backwards by 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go backwards.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go backwards_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go decend 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down 2 meter quickly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down 4 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go down 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go down 5m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go down 5m from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down and hover.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down at once.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down by 4m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down from here.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down lower.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down right away.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down slowly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down smoothly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go down.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go downward slightly_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 1.5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 10 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward 10m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward 10m from current position.m4a_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 10m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 27m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward 3 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 5 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 5 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 5 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 5 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 5 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward 5 meter from current position_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward 5m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward and stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward at once.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward from here.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward further.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward quickly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward right away.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward slowly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward smoothly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward till 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward until I say stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward upto 5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go forward_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go forward_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go higher 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go higher 10m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go left 10 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go left 10 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go left 10 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go left 10 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go left 10 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/go left 10 meter from current position_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left 20 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left 3 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left 3 meter_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left at once.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left by 5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left further.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left slowly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go left smoothly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 10 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 10 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 10 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 10 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 10 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 17m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right 5m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right at once.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Go right by 7m.mp3
# ...
#   inflating: downloaded_audio_fixed_to_mp3/Step the drone back 3 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Step the drone back 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop 0m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop 2 meter right away.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop 2m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop 5 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop 5 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop 5 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop 5 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop 5 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop 5 meter from current position_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 11 meters!.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 17m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 2 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop after 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop after 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 4 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop after 4 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop after 4 meters_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop after 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop after 5 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop and hover.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop and stay still.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop and stay still_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop at once.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop at your current location Dont move.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop at your current location.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop at your current location_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop from 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop from here.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop here only!.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop moving now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop moving now_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop moving now_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop moving now_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop moving now_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop moving now_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop moving now_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop now.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop now.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop quickly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop right there.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop right there_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop right there_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop right there_11.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop right there_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop right there_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop right there_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop right there_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop right there_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop right there_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop slowly after 1 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop slowly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop smoothly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stop.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Stope after traveling 7 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stop_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/stot at 2m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take a left after 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take of 5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take of 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off 0m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off 5 meter from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off 5 meter from current position_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off 5 meter from current position_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off 5 meter from current position_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off 5 meter from current position_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off 5 meter from current position_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off 5 meter.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off 5 meter_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off 5m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off and go higher.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off and hover.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off at once.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off drone immediately.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off from here.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off quickly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off right away.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off smoothly.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off straight up.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off to the sky.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_11.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_12.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_13.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_14.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_15.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_16.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Take off_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/take off_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/takeoff 10meter above from the current positionoff.mp3
#   inflating: downloaded_audio_fixed_to_mp3/takeoff 15meter above from the current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/takeoff 5m above from the current location.mp3
#   inflating: downloaded_audio_fixed_to_mp3/takeoff 5meter above from the current positionn.mp3
#   inflating: downloaded_audio_fixed_to_mp3/takeoff from the current position and movein the upward.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Takeoff from the ground from youtr current lif.mp3
#   inflating: downloaded_audio_fixed_to_mp3/That's enough for now, bring it in to land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/That's enough for now, bring it in to land_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/That's too high. Come down 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/That's too high. Come down 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/The battery is low, land the drone.mp3
#   inflating: downloaded_audio_fixed_to_mp3/thrn left 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to bring it down. Land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to bring it down. Land_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land the drone safely_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Time to land, drone.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Too close,. Go backward 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/too high, come down 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/touch ground 5m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/touch ground.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Travel Right 65m.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Travel right for 95 meters distance.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Travel right up to 70 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone left 3 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn drone left and move 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_10.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn drone right 3 meters_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn drone right and move 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left 30m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left 30m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left 30m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left 30m.mp3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn left after 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn left after 2 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn left after 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left after 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left after 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn left after 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left after 5 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left after 5 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn left from 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn left.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn left_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right 30m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right 30m from current position.m4a_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right 30m from current position.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right 30m.mp3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right 5m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn right after 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn right after 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right after 3 meters_2.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right after 3 meters_3.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn right after 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right after 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn right after 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right after 6 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/turn right after moving 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Turn right from 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/up 10m from current position.m4a.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Up 2 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Up 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Up 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/Watch behind! Go backward 1.5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We need more room, go backward 4 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We need more room, go backward 4 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We need to clear. Ascend another 5 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We need to get closer. Go forward by about 8 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We need to get closer. Go forward by about 8 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land_4.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land_5.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land_6.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land_7.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land_8.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're done here, execute landing procedure. Land_9.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're too close. Go backward 3 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're too close. Go backward 3 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're too low. Go up another 6 meters.mp3
#   inflating: downloaded_audio_fixed_to_mp3/We're too low. Go up another 6 meters_1.mp3
#   inflating: downloaded_audio_fixed_to_mp3/What's on the left side Pan left 6 meters.mp3

# %%
import os
import random
from pathlib import Path
import torch
import evaluate
from datasets import Dataset, DatasetDict, Audio
from transformers import (
    WhisperFeatureExtractor,
    WhisperTokenizer,
    WhisperProcessor,
    WhisperForConditionalGeneration,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer
)
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import audiomentations
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
from pydub import AudioSegment
import numpy as np
import librosa
import soundfile as sf
from tqdm import tqdm

# %%
def load_data(src='dataset', dst='dataset_processed'):
    os.makedirs(dst, exist_ok=True)
    mp3s = [f for f in os.listdir(src) if f.endswith('.mp3')]
    print(f"Found {len(mp3s)} files")

    a_paths, texts = [], []
    for i, f in enumerate(tqdm(mp3s, desc="Converting")):
        txt = f.replace('.mp3', '')
        src_p = os.path.join(src, f)
        dst_p = os.path.join(dst, f"{i:04d}.wav")
        try:
            a = AudioSegment.from_mp3(src_p).set_frame_rate(16000).set_channels(1)
            a.export(dst_p, format='wav')
            a_paths.append(dst_p)
            texts.append(txt)
        except Exception as e:
            print(f"Skip {f}: {e}")
    return a_paths, texts

print("Loading data...")
a_paths, texts = load_data()
print("Processed: ", len(a_paths))

def split_data(a_paths, texts, t_size=0.15):
    data = list(zip(a_paths, texts))
    random.seed(42)
    random.shuffle(data)
    s = int(len(data) * (1 - t_size))
    tr, ts = data[:s], data[s:]
    ta, tt = zip(*tr) if tr else ([], [])
    va, vt = zip(*ts) if ts else ([], [])
    return list(ta), list(tt), list(va), list(vt)

print("Splitting data...")
tr_a, tr_t, ts_a, ts_t = split_data(a_paths, texts)
print(f"train: {len(tr_a)}, Test: {len(ts_a)}")

def augment_data(a_paths, texts, factor=2):
    aug = Compose([
        AddGaussianNoise(0.001, 0.015, p=0.5),
        TimeStretch(0.9, 1.1, p=0.5),
        PitchShift(-2, 2, p=0.5),
        Shift(-0.5, 0.5, "fraction", rollover=False, p=0.3),
    ])
    aug_a, aug_t = [], []
    for i, (p, t) in enumerate(tqdm(zip(a_paths, texts), total=len(a_paths), desc="Augmenting")):
        try:
            s, sr = librosa.load(p, sr=16000, mono=True)
        except:
            continue
        aug_a.append(p)
        aug_t.append(t)
        for j in range(factor - 1):
            s2 = aug(samples=s, sample_rate=16000)
            out = f"dataset_processed/aug_{i}_{j}.wav"
            sf.write(out, s2, 16000)
            aug_a.append(out)
            aug_t.append(t)
    return aug_a, aug_t

print("augmenting...")
tr_a, tr_t = augment_data(tr_a, tr_t)
print(f"after aug: {len(tr_a)} samples")

class WhisperDS(torch.utils.data.Dataset):
    def __init__(self, a_p, txt, proc):
        self.a_p, self.txt, self.p = a_p, txt, proc
    def __len__(self): return len(self.a_p)
    def __getitem__(self, i):
        x, _ = librosa.load(self.a_p[i], sr=16000, mono=True)
        inp = self.p.feature_extractor(x, sampling_rate=16000, return_tensors="pt").input_features[0]
        lbl = self.p.tokenizer(self.txt[i]).input_ids
        return {"input_features": inp, "labels": lbl}

m_id = "openai/whisper-tiny"
print("loading model ", m_id)
f_ext = WhisperFeatureExtractor.from_pretrained(m_id)
tok = WhisperTokenizer.from_pretrained(m_id, language="English", task="transcribe")
proc = WhisperProcessor.from_pretrained(m_id, language="English", task="transcribe")

tr_ds = WhisperDS(tr_a, tr_t, proc)
ts_ds = WhisperDS(ts_a, ts_t, proc)
print(f"train DS: {len(tr_ds)}, Test DS: {len(ts_ds)}")

@dataclass
class Collator:
    proc: any
    dec_start: int
    def __call__(self, feats):
        inp = [{"input_features": f["input_features"]} for f in feats]
        batch = self.proc.feature_extractor.pad(inp, return_tensors="pt")
        lbls = [{"input_ids": f["labels"]} for f in feats]
        l_batch = self.proc.tokenizer.pad(lbls, return_tensors="pt")
        y = l_batch["input_ids"].masked_fill(l_batch.attention_mask.ne(1), -100)
        if (y[:, 0] == self.dec_start).all().cpu().item(): y = y[:, 1:]
        batch["labels"] = y
        return batch

print("trainer setup...")
model = WhisperForConditionalGeneration.from_pretrained(m_id)
model.generation_config.language = "english"
model.generation_config.task = "transcribe"
model.generation_config.forced_decoder_ids = None

coll = Collator(proc, model.config.decoder_start_token_id)
metric = evaluate.load("wer")

def metrics(pred):
    p_ids, l_ids = pred.predictions, pred.label_ids
    l_ids[l_ids == -100] = tok.pad_token_id
    p_str = tok.batch_decode(p_ids, skip_special_tokens=True)
    l_str = tok.batch_decode(l_ids, skip_special_tokens=True)
    return {"wer": 100 * metric.compute(predictions=p_str, references=l_str)}
# Out:
# augmenting...
# Augmenting: 100%|██████████| 1148/1148 [00:27<00:00, 41.42it/s]
# after aug: 2296 samples
# loading model  openai/whisper-tiny
# train DS: 2296, Test DS: 203
# trainer setup...

# %%
from transformers import EarlyStoppingCallback

# %%
import shutil
import os

folder_path = 'whisper-drone-command-final'
if os.path.exists(folder_path):
    shutil.rmtree(folder_path)
    print(f"Folder '{folder_path}' deleted successfully.")
else:
    print(f"Folder '{folder_path}' does not exist.")
# Out:
# Folder 'whisper-drone-command-final' deleted successfully.

# %%
args = Seq2SeqTrainingArguments(
    output_dir="./whisper-drone",
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,
    learning_rate=1e-5,
    warmup_steps=100,
    num_train_epochs=10,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_steps=10,
    fp16=True,
    predict_with_generate=True,
    generation_max_length=225,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=False,
    save_total_limit=2,
    remove_unused_columns=False,
)

stop_cb = EarlyStoppingCallback(
    early_stopping_patience=3,
    early_stopping_threshold=0.01
)

trainer = Seq2SeqTrainer(
    args=args,
    model=model,
    train_dataset=tr_ds,
    eval_dataset=ts_ds,
    data_collator=coll,
    compute_metrics=metrics,
    tokenizer=proc.feature_extractor,
    callbacks=[stop_cb],
)

#  early stopping patience=3, threshold=1%
trainer.train()
# Out:
# /tmp/ipython-input-3043654129.py:28: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# You're using a WhisperTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='864' max='1440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 864/1440 11:30 < 07:41, 1.25 it/s, Epoch 6/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.958500</td>
#       <td>1.847484</td>
#       <td>40.913327</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.508700</td>
#       <td>0.511926</td>
#       <td>33.178006</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.302100</td>
#       <td>0.452119</td>
#       <td>31.500466</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.189500</td>
#       <td>0.462052</td>
#       <td>47.343896</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.103700</td>
#       <td>0.479424</td>
#       <td>32.059646</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.084400</td>
#       <td>0.480311</td>
#       <td>63.560112</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py:3918: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50358, 50359, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# TrainOutput(global_step=864, training_loss=0.8988283615283392, metrics={'train_runtime': 690.7721, 'train_samples_per_second': 33.238, 'train_steps_per_second': 2.085, 'total_flos': 3.3914976141312e+17, 'train_loss': 0.8988283615283392, 'epoch': 6.0})

# %%
trainer.save_model("./whisper-drone-final")
proc.save_pretrained("./whisper-drone-final")
# Out:
# []

# %%
# !zip -r whisper-drone-command-final.zip whisper-drone-command-final/
print("zipped")
# Out:
#   adding: whisper-drone-command-final/ (stored 0%)
#   adding: whisper-drone-command-final/vocab.json (deflated 58%)
#   adding: whisper-drone-command-final/training_args.bin (deflated 54%)
#   adding: whisper-drone-command-final/tokenizer_config.json (deflated 96%)
#   adding: whisper-drone-command-final/merges.txt (deflated 54%)
#   adding: whisper-drone-command-final/model.safetensors (deflated 8%)
#   adding: whisper-drone-command-final/preprocessor_config.json (deflated 44%)
#   adding: whisper-drone-command-final/tokenizer.json (deflated 82%)
#   adding: whisper-drone-command-final/added_tokens.json (deflated 80%)
#   adding: whisper-drone-command-final/special_tokens_map.json (deflated 80%)
#   adding: whisper-drone-command-final/config.json (deflated 60%)
#   adding: whisper-drone-command-final/generation_config.json (deflated 71%)
#   adding: whisper-drone-command-final/normalizer.json (deflated 81%)
#
# Model zipped successfully!

# %%
import numpy as np, pandas as pd, torch, librosa, os, time
from tqdm import tqdm
from transformers import WhisperProcessor, WhisperForConditionalGeneration
from jiwer import wer
import evaluate

# %%
model = WhisperForConditionalGeneration.from_pretrained("./whisper-drone-final")
proc = WhisperProcessor.from_pretrained("./whisper-drone-final")

dev = "cuda" if torch.cuda.is_available() else "cpu"
model.to(dev).eval()

print(f"Device: {dev}")
print(f"Samples: {len(test_audio)}\n")

preds, refs, times = [], [], []
print("Running inference...")

for i, (p, ref) in enumerate(tqdm(zip(test_audio, test_text), total=len(test_audio))):
    try:
        s, _ = librosa.load(p, sr=16000, mono=True)
        inp = proc.feature_extractor(s, sampling_rate=16000, return_tensors="pt").input_features.to(dev)
        t0 = time.time()
        with torch.no_grad():
            ids = model.generate(inp)
            txt = proc.batch_decode(ids, skip_special_tokens=True)[0]
        times.append(time.time() - t0)
        preds.append(txt)
        refs.append(ref)
    except Exception as e:
        print(f"⚠️ Error at sample {i}: {e}")
        continue

print("\n=== METRICS ===")
m = evaluate.load("wer")
wer_score = m.compute(predictions=preds, references=refs)
print(f"WER: {wer_score*100:.2f}%")
print(f"Avg time/sample: {np.mean(times):.3f}s  |  Total: {np.sum(times):.2f}s")

print("\n=== STATS ===")
correct = sum(p.strip().lower() == r.strip().lower() for p, r in zip(preds, refs))
acc = (correct / len(refs)) * 100
print(f"Perfect: {correct}/{len(refs)} ({acc:.2f}%)")
print(f"Errors: {len(refs) - correct}/{len(refs)}")

w_list = [wer(r, p) if r and p else 1.0 for p, r in zip(preds, refs)]
print(f"Mean: {np.mean(w_list)*100:.2f}% | Median: {np.median(w_list)*100:.2f}% | Min: {np.min(w_list)*100:.2f}% | Max: {np.max(w_list)*100:.2f}% | Std: {np.std(w_list)*100:.2f}%")

print("\n=== SAMPLE PREDICTIONS ===")
for i in range(min(10, len(preds))):
    wv = w_list[i] * 100
    print(f"\n{'✅' if wv==0 else '❌'} {i+1}. WER {wv:.1f}%")
    print(f"Ref: {refs[i]}")
    print(f"Pred: {preds[i]}")

print("\n=== WORST PREDICTIONS ===")
bad_idx = np.argsort(w_list)[-5:][::-1]
for r, i in enumerate(bad_idx, 1):
    print(f"\n{r}. {i+1} (WER {w_list[i]*100:.1f}%)")
    print(f"Ref: {refs[i]}")
    print(f"Pred: {preds[i]}")

print("\n=== MODERATE ERRORS ===")
mid = [(i, w) for i, w in enumerate(w_list) if 0 < w < 0.3]
if mid:
    for r, (i, w) in enumerate(sorted(mid, key=lambda x: x[1])[:5], 1):
        print(f"\n{r}. {i+1} (WER {w*100:.1f}%)")
        print(f"Ref: {refs[i]}")
        print(f"Pred: {preds[i]}")
else:
    print("None found.")

print("\n=== SAVING RESULTS ===")
df = pd.DataFrame({
    "id": range(1, len(preds)+1),
    "file": [os.path.basename(p) for p in test_audio],
    "ref": refs,
    "pred": preds,
    "wer": [w*100 for w in w_list],
    "time": times,
    "match": [p.strip().lower()==r.strip().lower() for p, r in zip(preds, refs)]
})
df.to_csv("test_results_detailed.csv", index=False)
print("Saved detailed results.")

summary = {
    "Samples": len(refs),
    "WER (%)": round(wer_score*100, 2),
    "Perfect": correct,
    "Acc (%)": round(acc, 2),
    "Mean WER (%)": round(np.mean(w_list)*100, 2),
    "Median WER (%)": round(np.median(w_list)*100, 2),
    "Std WER (%)": round(np.std(w_list)*100, 2),
    "Avg Time (s)": round(np.mean(times), 3),
    "Total Time (s)": round(np.sum(times), 2)
}
pd.DataFrame([summary]).to_csv("test_results_summary.csv", index=False)
print("Saved summary.\n\n=== EVALUATION DONE ===")
# Out:
# Device: cuda
# Samples: 203
#
# Running inference...
# 100%|██████████| 203/203 [00:14<00:00, 13.91it/s]
# === METRICS ===
# WER: 31.50%
# Avg time/sample: 0.056s  |  Total: 11.42s
#
# === STATS ===
# Perfect: 68/203 (33.50%)
# Errors: 135/203
# Mean: 35.20% | Median: 27.27% | Min: 0.00% | Max: 150.00% | Std: 33.05%
#
# === SAMPLE PREDICTIONS ===
#
# ❌ 1. WER 40.0%
# Ref: Turn drone right 3 meters_1
# Pred:  turn drone right 3 meters
#
# ✅ 2. WER 0.0%
# Ref: Drone, go up 6 meters
# Pred: Drone, go up 6 meters
#
# ❌ 3. WER 100.0%
# Ref: Drone go down 3 meters_2
# Pred:  Go move backward now
#
# ❌ 4. WER 33.3%
# Ref: Drone land now
# Pred:  Drone, land now
#
# ❌ 5. WER 25.0%
# Ref: Stop after 11 meters!
# Pred:  Stop after 11 meters
#
# ❌ 6. WER 16.7%
# Ref: shift right 0m from current position.m4a
# Pred:  safe right 0m from current position.m4a
#
# ✅ 7. WER 0.0%
# Ref: Proceed straight up 75 meters
# Pred:  Proceed straight up 75 meters
#
# ❌ 8. WER 20.0%
# Ref: Drone move down 1 meter
# Pred:  drone move down 1 meter
#
# ❌ 9. WER 60.0%
# Ref: descend down by 19 meter
# Pred:  Descend down by 19m
#
# ✅ 10. WER 0.0%
# Ref: Drone stop after 2 meters
# Pred: Drone stop after 2 meters
#
# === WORST PREDICTIONS ===
#
# 1. 193 (WER 150.0%)
# Ref: Emergency stop_4
# Pred:  Images the stop
#
# 2. 95 (WER 150.0%)
# Ref: lower 30m
# Pred:  lower 30m from current position
#
# 3. 93 (WER 150.0%)
# Ref: fly 25m
# Pred: fly 25m from current position
#
# 4. 12 (WER 150.0%)
# Ref: Move Right For 90m
# Pred:  Tray well, ride forward 90 meters
#
# 5. 69 (WER 140.0%)
# Ref: Let's strafe left 1 meter_1
# Pred:  Can you pan left by about 5 meters
#
# === MODERATE ERRORS ===
#
# 1. 141 (WER 9.1%)
# Ref: move 15 metre in the downward direction from your current location
# Pred: move 50 metre in the downward direction from your current location
#
# 2. 15 (WER 12.5%)
# Ref: please go forward 10 meter from current position_4
# Pred:  please go forward 10 meter from current position
#
# 3. 35 (WER 12.5%)
# Ref: Let's see what you can do. Take off_8
# Pred:  Let's see what you can do. Take off
#
# 4. 125 (WER 12.5%)
# Ref: Bring it home. Land in the designated zone_6
# Pred:  Bring it home. Land in the designated zone
#
# 5. 186 (WER 12.5%)
# Ref: Let's see what you can do. Take off_4
# Pred:  Let's see what you can do. Take off
#
# === SAVING RESULTS ===
# Saved detailed results.
# Saved summary.
#
# === EVALUATION DONE ===
